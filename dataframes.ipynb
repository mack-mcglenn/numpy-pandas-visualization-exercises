# %%
import numpy as np

import pandas as pd

from pydataset import data

# %%
# All the datasets loaded from the pydataset library will be pandas dataframes.

#     Copy the code from the lesson to create a dataframe full of student grades.
#         Create a column named passing_english that indicates whether each student has a passing grade in english.
#         Sort the english grades by the passing_english column. How are duplicates handled?
#         Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered alphabetically. The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)
#         Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.
#         Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas', 'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# %%
math_grades = np.random.randint(low=60, high=100, size=len(students))

english_grades = np.random.randint(low=60, high=100, size=len(students))

reading_grades = np.random.randint(low=60, high=100, size=len(students))

np.random.seed(123)

# %%
readin = reading_grades
writin = english_grades
rithmetic = math_grades
kids = students

df_dict = {'Student': kids,
                   'Math': rithmetic,
                   'English': writin,
                   'Reading': readin}
df
# Out:
#     Student  Math  English  Reading  Passing English  Overall Grade
# 0     Sally    62       85       80             True          75.67
# 1      Jane    88       79       67             True          78.00
# 2     Suzie    94       74       95             True          87.67
# 3     Billy    98       96       88             True          94.00
# 4       Ada    77       92       98             True          89.00
# 5      John    79       76       93             True          82.67
# 6    Thomas    82       64       81            False          75.67
# 7     Marie    93       63       90            False          82.00
# 8    Albert    92       62       87            False          80.33
# 9   Richard    69       80       94             True          81.00
# 10    Isaac    92       99       93             True          94.67
# 11     Alan    92       62       72            False          75.33

# %%
df = pd.DataFrame(df_dict)
df
# Out:
#     Student  Math  English  Reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
df['Reading']
# Out:
# 0     80
# 1     67
# 2     95
# 3     88
# 4     98
# 5     93
# 6     81
# 7     90
# 8     87
# 9     94
# 10    93
# 11    72
# Name: Reading, dtype: int64

# %%
# Exercise 1.1: Create a column named passing_english that indicates whether
# each student has a passing grade in english.
pass_e = 'Passing English' 
pass_e
df[pass_e] = df.English > 70
df[]
# df.drop(columns=['Passing_English'])
# df
# Out:
# 0     80
# 1     67
# 2     95
# 3     88
# 4     98
# 5     93
# 6     81
# 7     90
# 8     87
# 9     94
# 10    93
# 11    72
# Name: Reading, dtype: int64

# %%
kids ='Student'
rithmetic = 'Math'
writin = 'Enlgish'
readin = 'Reading'
df.sort_values(kids)
# Out:
#     Student  Math  English  Reading  Passing English
# 4       Ada    77       92       98             True
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 7     Marie    93       63       90            False
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True
# 6    Thomas    82       64       81            False

# %%
# Exercise 1.2 Sort the english grades by the passing_english column. 
# How are duplicates handled?
# A: The duplicates are ordered by primary key

df.sort_values(by= 'Passing English')
# Out:
#     Student  Math  English  Reading  Passing English  Overall Grade
# 6    Thomas    82       64       81            False          75.67
# 7     Marie    93       63       90            False          82.00
# 8    Albert    92       62       87            False          80.33
# 11     Alan    92       62       72            False          75.33
# 0     Sally    62       85       80             True          75.67
# 1      Jane    88       79       67             True          78.00
# 2     Suzie    94       74       95             True          87.67
# 3     Billy    98       96       88             True          94.00
# 4       Ada    77       92       98             True          89.00
# 5      John    79       76       93             True          82.67
# 9   Richard    69       80       94             True          81.00
# 10    Isaac    92       99       93             True          94.67

# %%
# Sort the english grades first by passing_english and then by student name. All the students
# that are failing english should be first, and within the students that are failing 
# english they should be ordered alphabetically. The same should be true for the students 
# passing english. (Hint: you can pass a list to the .sort_values method)


dfs = df.sort_values(['Passing English', 'Student'], ascending = [True, True])
dfs
# Out:
#     Student  Math  English  Reading  Passing English  Overall Grade
# 11     Alan    92       62       72            False          75.33
# 8    Albert    92       62       87            False          80.33
# 7     Marie    93       63       90            False          82.00
# 6    Thomas    82       64       81            False          75.67
# 4       Ada    77       92       98             True          89.00
# 3     Billy    98       96       88             True          94.00
# 10    Isaac    92       99       93             True          94.67
# 1      Jane    88       79       67             True          78.00
# 5      John    79       76       93             True          82.67
# 9   Richard    69       80       94             True          81.00
# 0     Sally    62       85       80             True          75.67
# 2     Suzie    94       74       95             True          87.67

# %%
# Exercise 1.4: Sort the english grades first by passing_english, and then by the actual
#english grade, similar to how we did in the last step.

dfs.sort_values(by = ['Passing English', 'English'], ascending = [True, False])
# Out:
#     Student  Math  English  Reading  Passing English  Overall Grade
# 6    Thomas    82       64       81            False          75.67
# 7     Marie    93       63       90            False          82.00
# 11     Alan    92       62       72            False          75.33
# 8    Albert    92       62       87            False          80.33
# 10    Isaac    92       99       93             True          94.67
# 3     Billy    98       96       88             True          94.00
# 4       Ada    77       92       98             True          89.00
# 0     Sally    62       85       80             True          75.67
# 9   Richard    69       80       94             True          81.00
# 1      Jane    88       79       67             True          78.00
# 5      John    79       76       93             True          82.67
# 2     Suzie    94       74       95             True          87.67

# %%
# Exercise 1.5: Calculate each students overall grade and add it as a column on
df['Overall Grade'] = round((dfs.Math + dfs.English + dfs.Reading)/3, 2)
df
# Out:
#     Student  Math  English  Reading  Passing English  Overall Grade
# 0     Sally    62       85       80             True          75.67
# 1      Jane    88       79       67             True          78.00
# 2     Suzie    94       74       95             True          87.67
# 3     Billy    98       96       88             True          94.00
# 4       Ada    77       92       98             True          89.00
# 5      John    79       76       93             True          82.67
# 6    Thomas    82       64       81            False          75.67
# 7     Marie    93       63       90            False          82.00
# 8    Albert    92       62       87            False          80.33
# 9   Richard    69       80       94             True          81.00
# 10    Isaac    92       99       93             True          94.67
# 11     Alan    92       62       72            False          75.33

# %%
Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:
    How many rows and columns are there?
    What are the data types of each column?
    Summarize the dataframe with .info and .describe
    Rename the cty column to city.
    Rename the hwy column to highway.
    Do any cars have better city mileage than highway mileage?
    Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.
    Which car (or cars) has the highest mileage difference?
    Which compact class car has the lowest highway mileage? The best?
    Create a column named average_mileage that is the mean of the city and highway mileage.
    Which dodge car has the best average mileage? The worst?

mpg = data('mpg')

# %%
# Exercise 2.1: How many rows and columns are there?
# A:(234, 12)

mpg.shape
# Out:
# (234, 12)

# %%
# Exercise 2.2: What are the data types of each column?
# A:
# Objects: manufacturer, model, trans, drv, fl, class
# Floats: displ
# Integers: year, cyl, City, Highway

mpg.info()
#can also use .dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   manufacturer        234 non-null    object
#  1   model               234 non-null    object
#  2   displ               234 non-null    float64
#  3   year                234 non-null    int64
#  4   cyl                 234 non-null    int64
#  5   trans               234 non-null    object
#  6   drv                 234 non-null    object
#  7   City                234 non-null    int64
#  8   Highway             234 non-null    int64
#  9   fl                  234 non-null    object
#  10  class               234 non-null    object
#  11  Mileage Difference  234 non-null    int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 23.8+ KB

# %%
#Exercise 2.3: Summarize the dataframe with .info and .describe

mpg.info()


mpg.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   manufacturer        234 non-null    object
#  1   model               234 non-null    object
#  2   displ               234 non-null    float64
#  3   year                234 non-null    int64
#  4   cyl                 234 non-null    int64
#  5   trans               234 non-null    object
#  6   drv                 234 non-null    object
#  7   City                234 non-null    int64
#  8   Highway             234 non-null    int64
#  9   fl                  234 non-null    object
#  10  class               234 non-null    object
#  11  Mileage Difference  234 non-null    int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 23.8+ KB
#             displ         year         cyl        City     Highway  \
# ...

# %%
# Exercise 2.4: Rename the cty column to city.

mpg = mpg.rename(columns={'cty': 'City'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  City  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ...

# %%
# Exercise 2.5: Rename the hwy column to highway.

mpg = mpg.rename(columns={'hwy': 'Highway'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  City  Highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %%
# Exercise 2.5: Do any cars have better city mileage than highway mileage?

# def best_mpg(x):
#     if mpg.City > mpg.Highway:
#         return x
#     else:
#         return False
    


mpg_cithi = mpg[mpg.City > mpg.Highway]
len(mpg_cithi)
# Out:
# 0

# %%
# Exercise 2.6:Create a column named mileage_difference this column should contain the
# difference between highway and city mileage for each car.

mile_dif = 'Mileage Difference' 

mpg[mile_dif] = mpg.Highway - mpg.City
# mpg[mile_dif] == mpg['Mileage Difference']
# mpg[mile_dif]
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  City  Highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  Mileage Difference
# ...

# %%
# Exercise 2.6: Which car (or cars) has the highest mileage difference?
mpg[mpg[mile_dif]== mpg[mile_dif].max()]
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  City  Highway  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f    24       36
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f    29       41
#
#     fl       class  Mileage Difference
# 107  c  subcompact                  12
# 223  d  subcompact                  12

# %%
# Exercise 2.7: Which compact class car has the lowest highway mileage? The best?
# A: Volkswagen Jetta 2.8l

comp_class = mpg[mpg['class'] == 'compact']

comp_class[comp_class['Highway'] == comp_class['Highway'].min()]
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  City  Highway fl  \
# 220   volkswagen  jetta    2.8  1999    6  auto(l4)   f    16       23  r
#
#        class  Mileage Difference
# 220  compact                   7

# %%
# Exercise 2.8: Create a column named average_mileage that is the mean of the city and highway mileage.

avg_mi = 'Average Mileage'
mpg[avg_mi] = (mpg.City + mpg.Highway)/2
mpg[avg_mi]
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  City  Highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %%
# Exercise 2.9: Which dodge car has the best average mileage? The worst?

dodge = mpg[mpg['manufacturer'] == 'dodge']

dodge[dodge[avg_mi] == dodge[avg_mi].min()]

# A: Worst avg: Dodge Ram 1500, Durango, and Dakota pickup (all 4.7l)
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  City  \
# 55        dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60        dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 66        dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
#
#     Highway fl   class  Mileage Difference  Average Mileage
# 55       12  e  pickup                   3             10.5
# 60       12  e     suv                   3             10.5
# 66       12  e  pickup                   3             10.5
# 70       12  e  pickup                   3             10.5

# %%
dodge[dodge[avg_mi] == dodge[avg_mi].max()]

#Best: Dodge Caravan 2.4l
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  City  Highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
#
#    fl    class  Mileage Difference  Average Mileage
# 38  r  minivan                   6             21.0

# %%
Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:

    How many rows and columns are there?
    What are the data types?
    Summarize the dataframe with .info and .describe
    What is the the weight of the fastest animal?
    What is the overal percentage of specials?
    How many animals are hoppers that are above the median speed? What percentage is this?

# %%
mamdf = data('Mammals')
mamdf
# Out:
#        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %%
#Exercise 3.1: How many rows and columns are there?

mamdf.shape
# Out:
# (107, 4)

# %%
# Exercise 3.2: What are the data types?

mamdf.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %%
# Exercise 3.3: Summarize the dataframe with .info and .describe

mamdf.info()

mamdf.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %%
# Exercise 3.4: What is the the weight of the fastest animal?


mamdf['weight'].value().max()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/3f/gcykrn_x5kj_vxldk0lkx7p00000gn/T/ipykernel_74530/1235748651.py in <module>
#       2
#       3
# ----> 4 mamdf['weight'].value().max()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value'

# %%
# Execise 3.5: What is the overal percentage of specials?

mamdf['specials'].value_counts(normalize = True)

# %%
mamdf[mamdf['hoppers']]

mamdf[mamdf['speed'] > mamdf['speed'].median()]
# Out:
#      weight  speed  hoppers  specials
# 5     400.0   70.0    False     False
# 6     350.0   70.0    False     False
# 7     300.0   64.0    False     False
# 8     260.0   70.0    False     False
# 11   1000.0   60.0    False     False
# 12    900.0   70.0    False     False
# 13    900.0   56.0    False     False
# 15    750.0   57.0    False     False
# 17    450.0   56.0    False     False
# 18    300.0   72.0    False     False
# 19    300.0   90.0    False     False
# 20    250.0   80.0    False     False
# 21    250.0   56.0    False     False
# 22    170.0   80.0    False     False
# 24    130.0   70.0    False     False
# 25    120.0   80.0    False     False
# 26    120.0   61.0    False     False
# 28    100.0   64.0    False     False
# 29     85.0   55.0    False     False
# 30     80.0   65.0    False     False
# 31     72.0   56.0    False     False
# 33     65.0   60.0    False     False
# 34     62.0   81.0    False     False
# 35     50.0  100.0    False     False
# ...

# %%
mamdf[(mamdf['hoppers'] == True) & (mamdf['speed'] > mamdf['speed'].median())]
# Out:
#      weight  speed  hoppers  specials
# 96      4.6   64.0     True     False
# 97      4.4   72.0     True     False
# 98      4.0   72.0     True     False
# 99      3.5   56.0     True     False
# 100     2.0   64.0     True     False
# 101     1.9   56.0     True     False
# 102     1.5   50.0     True     False
