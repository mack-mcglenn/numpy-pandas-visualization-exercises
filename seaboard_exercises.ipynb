# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Use the iris database to answer the following questions:
sdf = sns.load_dataset('iris')
sdf
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sdf.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
sdf.shape
# Out:
# (150, 5)

# %%
# Exrecise 1.1. What does the distribution of petal lengths look like?

sns.displot(data=sdf, x='petal_length', kde=True)

# %%
sns.displot(data=sdf, x='petal_length', kde=True)
plt.show()

# %%
# Exercise 1.2. Is there a correlation between petal length and petal width? Use guessthecorrelation.com/ 
# as a hint to how we could visually determine if a correlation exists between two numeric 
# columns.

# A: There appears to be a positive correlation between the length of a pedal and how wide
# it will be. Longer petals seem to be wider.

sns.relplot(x= 'petal_length', y= 'petal_width', hue = 'species', data=sdf)
plt.show()

# %%
# Exercise 1.3 Would it be reasonable to predict species based on sepal width and sepal length? For this, 
# you'll visualize two numeric columns through the lense of a categorical column.

# A: Kind of, we can see that setosa is consistently predictable.
sns.boxplot(x='sepal_length', y='sepal_width', hue = 'species', data=sdf)
plt.show()

# %%
sns.swarmplot(
y='sepal_length',
x='sepal_width', data=sdf)
    
plt.show()
# Out:
# /Users/mackbookair/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 11.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.lmplot(
x='sepal_length',
y='sepal_width', data=sdf)
    
plt.show()

# %%
sns.relplot(
x='sepal_length',
y='sepal_width', data=sdf)
    
plt.show()

# %%
# Exercise 1.4. Which features would be best used to predict species? 
# A: Pairplot

# %%
# Using the lesson as an example, use seaborn's load_dataset function to load the anscombe
# data set. Use pandas to group the data by the dataset column, and calculate summary 
# statistics for each dataset. What do you notice?

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
ans = sns.load_dataset('anscombe')
ans
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
#A: There appears to be a lot of similarities in the statistical data for the 
# x-values and y-values, like the same means and stddev.

ans.groupby('dataset').agg(['describe'])
# Out:
#                x                                                  y            \
#         describe                                           describe
#            count mean       std  min  25%  50%   75%   max    count      mean
# dataset
# I           11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0     11.0  7.500909
# II          11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0     11.0  7.500909
# III         11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0     11.0  7.500000
# IV          11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0     11.0  7.500909
#
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %%
# Exercise 2.1 Plot the x & y values from the anscombe data. Each dataset should be in a separate column.

sns.relplot(x='x', y='y', col='dataset', data=ans)
plt.show()

# %%
# Exercise 2.2 Load the InsectSprays dataset and read it's documentation. 
# Create a boxplot that shows the effectiveness of the different insect sprays.

from pydataset import data
bugspray =data("InsectSprays")
bugspray
# Out:
#     count spray
# 1      10     A
# 2       7     A
# 3      20     A
# 4      14     A
# 5      14     A
# 6      12     A
# 7      10     A
# 8      23     A
# 9      17     A
# 10     20     A
# 11     14     A
# 12     13     A
# 13     11     B
# 14     17     B
# 15     21     B
# 16     11     B
# 17     16     B
# 18     14     B
# 19     17     B
# 20     17     B
# 21     19     B
# 22     21     B
# 23      7     B
# 24     13     B
# 25      0     C
# 26      1     C
# 27      7     C
# 28      2     C
# 29      3     C
# 30      1     C
# 31      2     C
# 32      1     C
# 33      3     C
# 34      0     C
# 35      1     C
# 36      4     C
# 37      3     D
# 38      5     D
# 39     12     D
# 40      6     D
# 41      4     D
# 42      3     D
# 43      5     D
# 44      5     D
# 45      5     D
# 46      5     D
# 47      2     D
# 48      4     D
# 49      3     E
# 50      5     E
# 51      3     E
# 52      5     E
# 53      3     E
# 54      6     E
# ...

# %%
sns.boxplot(y='count',x='spray', data=bugspray)
plt.title("Effectiveness of Different Insect Sprays")
plt.show()

# %%
# Exrecise 2.3 Load the swiss dataset and read it's documentation. The swiss dataset is 
# available from pydatset rather than seaborn. Create visualizations to answer the 
# following questions:

swiss= data('swiss')
swiss
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
# Veveyse            87.1         64.5           14          6     98.61
# Aigle              64.1         62.0           21         12      8.52
# ...

# %%
# Exercise 2.3.1 Create an attribute named is_catholic that holds a boolean value of whether
# or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)

swiss['is_catholic']= swiss['Catholic'] > 62.01
is_catholic
# Out:
# Courtelary      False
# Delemont         True
# Franches-Mnt     True
# Moutier         False
# Neuveville      False
# Porrentruy       True
# Broye            True
# Glane            True
# Gruyere          True
# Sarine           True
# Veveyse          True
# Aigle           False
# Aubonne         False
# Avenches        False
# Cossonay        False
# Echallens       False
# Grandson        False
# Lausanne        False
# La Vallee       False
# Lavaux          False
# Morges          False
# Moudon          False
# Nyone           False
# Orbe            False
# Oron            False
# Payerne         False
# Paysd'enhaut    False
# Rolle           False
# Vevey           False
# Yverdon         False
# Conthey          True
# Entremont        True
# Herens           True
# Martigwy         True
# Monthey          True
# St Maurice       True
# Sierre           True
# Sion             True
# Boudry          False
# La Chauxdfnd    False
# Le Locle        False
# ...

# %%
swiss
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
# Veveyse            87.1         64.5           14          6     98.61
# Aigle              64.1         62.0           21         12      8.52
# ...

# %%
# Exercise 2.3.2 Does whether or not a province is Catholic influence fertility?
sns.boxplot(y='Fertility', x='is_catholic', data=swiss)
plt.title("Does Regional Catholic Influence Affect Fertility?")
plt.show()

# %%
# Exercise 2.3.3 What measure correlates most strongly with fertility?
# A: None are particularly strong correlations
sns.pairplot(swiss, hue='is_catholic')
plt.show()

# %%
swiss.corr()
# Out:
#                   Fertility  Agriculture  Examination  Education  Catholic  \
# Fertility          1.000000     0.353079    -0.645883  -0.663789  0.463685
# Agriculture        0.353079     1.000000    -0.686542  -0.639523  0.401095
# Examination       -0.645883    -0.686542     1.000000   0.698415 -0.572742
# Education         -0.663789    -0.639523     0.698415   1.000000 -0.153859
# Catholic           0.463685     0.401095    -0.572742  -0.153859  1.000000
# Infant.Mortality   0.416556    -0.060859    -0.114022  -0.099322  0.175496
# is_catholic        0.605023     0.475120    -0.641897  -0.328808  0.957798
#
#                   Infant.Mortality  is_catholic
# Fertility                 0.416556     0.605023
# Agriculture              -0.060859     0.475120
# Examination              -0.114022    -0.641897
# Education                -0.099322    -0.328808
# Catholic                  0.175496     0.957798
# Infant.Mortality          1.000000     0.207544
# ...

# %%
from env import username, password, host

# %%
# Exercise 3.1 Using the chipotle dataset from the previous exercise, create a bar chart
# that shows the 4 most popular items and the revenue produced by each.


def get_db_url(username, password, host, db):
  
    url = f'mysql+pymysql://{username}:{password}@{host}/{db}'
    return url

# %%
gross = get_db_url(username, password, host, 'chipotle')

# %%
gross_guac= pd.read_sql('select * from orders', gross)
gross_guac.head(21)
# Out:
#     id  order_id  quantity                              item_name  \
# 0    1         1         1           Chips and Fresh Tomato Salsa
# 1    2         1         1                                   Izze
# 2    3         1         1                       Nantucket Nectar
# 3    4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4    5         2         2                           Chicken Bowl
# 5    6         3         1                           Chicken Bowl
# 6    7         3         1                          Side of Chips
# 7    8         4         1                          Steak Burrito
# 8    9         4         1                       Steak Soft Tacos
# 9   10         5         1                          Steak Burrito
# 10  11         5         1                    Chips and Guacamole
# 11  12         6         1                   Chicken Crispy Tacos
# 12  13         6         1                     Chicken Soft Tacos
# ...

# %%
# I need to convert my dtype for 'item_price' into a float
gross_guac['item_price']=gross_guac['item_price'].str.replace('$', '')
gross_guac['item_price'] = gross_guac['item_price'].astype(float)
gross_guac['item_price']
# Out:
# /var/folders/3f/gcykrn_x5kj_vxldk0lkx7p00000gn/T/ipykernel_84374/2309906157.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   gross_guac['item_price']=gross_guac['item_price'].str.replace('$', '')
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
# Then, I group by 'item_name' and use my sum function to get a total float value for my
# item price/int value for my quantity
top_sellers= gross_guac.groupby('item_name').sum()
top_sellers
# Out:
#                                             id  order_id  quantity  item_price
# item_name
# 6 Pack Soft Drink                       130372     52322        55      356.95
# Barbacoa Bowl                           134330     53972        66      672.36
# Barbacoa Burrito                        186070     74718        91      894.75
# Barbacoa Crispy Tacos                    13836      5613        12      120.21
# Barbacoa Salad Bowl                      24171      9708        10      106.40
# Barbacoa Soft Tacos                      46479     18725        25      250.46
# Bottled Water                           439516    175944       211      302.56
# Bowl                                      1120       472         4       29.60
# Burrito                                   3740      1550         6       44.40
# Canned Soda                             190019     76396       126      137.34
# Canned Soft Drink                       760291    304753       351      438.75
# ...

# %%
# Next, I neet to organize my table to show my highest quantity items at the top
# A: Top 4 sellers: Chicken Bowl, Chicken Burrito, Chips & Guac, Steak Burrito

dry_chicken = top_sellers.sort_values(by='quantity', ascending=False).head(4)
dry_chicken
# Out:
#                           id  order_id  quantity  item_price
# item_name
# Chicken Bowl         1780635    713926       761     7342.73
# Chicken Burrito      1238770    497303       591     5575.82
# Chips and Guacamole  1122252    449959       506     2201.04
# Steak Burrito         818163    328437       386     3851.43

# %%
# To find my items bringing in the most revenue, I use the same function as the last block,
# but I sort by 'item_price' rather than 'quantity'

# A: Top sellers by revenue: Chicken Bowl, Chicken Burrito, Steak Burrito, Steak Bowl

cold_stale_chips= top_sellers.sort_values(by='item_price', ascending=False).reset_index().head(4)
cold_stale_chips
# Out:
#          item_name       id  order_id  quantity  item_price
# 0     Chicken Bowl  1780635    713926       761     7342.73
# 1  Chicken Burrito  1238770    497303       591     5575.82
# 2    Steak Burrito   818163    328437       386     3851.43
# 3       Steak Bowl   482932    193752       221     2260.19

# %%
sns.set_style('darkgrid')
sns.barplot(y='item_name', x='item_price', data=cold_chips)
plt.title("Most Popular Items by Revenue")
plt.xlabel("Revenue Per Item")
plt.ylabel("Item Name")
plt.show()

# %%
sns.set_style('darkgrid')
sns.barplot(y='item_name', x='quantity', data=cold_chips)
plt.title("Most Popular Items by Quantity")
plt.xlabel("Item Quantity")
plt.ylabel("Item Name")
plt.show()

# %%
# Load the sleepstudy data and read it's documentation. Use seaborn to create a line chart
# of all the individual subject's reaction times and a more prominant line 
# showing the average change in reaction time.

sleepytime=data('sleepstudy')

sleepytime
# Out:
#      Reaction  Days  Subject
# 1    249.5600     0      308
# 2    258.7047     1      308
# 3    250.8006     2      308
# 4    321.4398     3      308
# 5    356.8519     4      308
# ..        ...   ...      ...
# 176  329.6076     5      372
# 177  334.4818     6      372
# 178  343.2199     7      372
# 179  369.1417     8      372
# 180  364.1236     9      372
#
# [180 rows x 3 columns]

# %%
sleepysubs= sleepytime.sort_values(by='Subject')
sleepysubs
# Out:
#      Reaction  Days  Subject
# 1    249.5600     0      308
# 2    258.7047     1      308
# 3    250.8006     2      308
# 4    321.4398     3      308
# 5    356.8519     4      308
# ..        ...   ...      ...
# 175  287.1726     4      372
# 176  329.6076     5      372
# 177  334.4818     6      372
# 178  343.2199     7      372
# 180  364.1236     9      372
#
# [180 rows x 3 columns]

# %%
# I need to convert Subject to an object instead on an integer 
sleepytime.dtypes
# Out:
# Reaction    float64
# Days          int64
# Subject       int64
# dtype: object

# %%
sleepysubs['Subject']= sleepysubs['Subject'].astype(object)
sleepysubs['Subject']
# Out:
# 1      308
# 2      308
# 3      308
# 4      308
# 5      308
#       ...
# 175    372
# 176    372
# 177    372
# 178    372
# 180    372
# Name: Subject, Length: 180, dtype: object

# %%
sns.lineplot(x='Days', y='Reaction', data=sleepysubs, hue='Subject', 
             legend = False)
sns.lineplot(x='Days', y='Reaction', data=sleepysubs, estimator = 'mean'
             , color = 'black')
plt.title('Reaction Time of Subjects Overtime')
plt.xlabel('Reaction Time in MS')
plt.ylabel('Days of Sleep Deprivation')
plt.show()
